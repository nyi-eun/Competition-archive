# %%
import pandas as pd

# %%
Y=pd.read_csv('df_시군구_합계출산율.csv',encoding='cp949')
X1=pd.read_csv('df_평균초혼연령.csv',encoding='cp949')
X2=pd.read_csv('df_1인가구비율.csv',encoding='cp949')
X3=pd.read_csv('df_행정구역별_경제활동인구.csv',encoding='cp949')
X4=pd.read_csv('소비자물가지수.csv',encoding='cp949')
X5=pd.read_csv('df_사교육비.csv',encoding='cp949')
X6=pd.read_csv('유아 천명당 보육시설수.csv',encoding='cp949')
X7=pd.read_csv('df_인구밀도.csv',encoding='cp949',thousands = ',')

# %% [markdown]
# ### 1) Y: 합계출산율

# %%
Y.head()
# Out:
#    행정구역별   2015   2016   2017   2018   2019   2020
# 0     전국  1.239  1.172  1.052  0.977  0.918  0.837
# 1  서울특별시  1.001  0.940  0.836  0.761  0.717  0.642
# 2  부산광역시  1.139  1.095  0.976  0.899  0.827  0.747
# 3  대구광역시  1.216  1.186  1.067  0.987  0.932  0.807
# 4  인천광역시  1.216  1.144  1.007  1.006  0.940  0.829

# %%
Y1=Y[['행정구역별','2015']]
Y2=Y[['행정구역별','2016']]
Y3=Y[['행정구역별','2017']]
Y4=Y[['행정구역별','2018']]
Y5=Y[['행정구역별','2019']]
Y6=Y[['행정구역별','2020']] # 각각의 변수에 년도별 데이터프레임 생성
Y2.rename(columns = {'2016':'2015'},inplace=True)
Y3.rename(columns = {'2017':'2015'},inplace=True)
Y4.rename(columns = {'2018':'2015'},inplace=True)
Y5.rename(columns = {'2019':'2015'},inplace=True)
Y6.rename(columns = {'2020':'2015'},inplace=True) # 컬럼 이름을 하나로 통일
Y= pd.concat([Y1,Y2,Y3,Y4,Y5,Y6],axis=0);Y # 컬럼 이름 통일 후, 열 합치기
Y.rename(columns = {'2015':'합계출산율'},inplace=True);Y #이름을 합계출산율로 바꾸기
# Out:
# C:\Users\kim ji eun\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       행정구역별  합계출산율
# 0        전국  1.239
# 1     서울특별시  1.001
# 2     부산광역시  1.139
# 3     대구광역시  1.216
# 4     인천광역시  1.216
# ..      ...    ...
# 13     전라북도  0.909
# 14     전라남도  1.145
# 15     경상북도  1.003
# 16     경상남도  0.945
# 17  제주특별자치도  1.021
#
# [108 rows x 2 columns]

# %% [markdown]
# ### 2) X1: 평균초혼연령

# %%
X1.head()
# Out:
#    행정구역별   2015   2016   2017   2018   2019   2020
# 0     전국  29.96  30.11  30.24  30.40  30.59  30.78
# 1  서울특별시  30.80  31.01  31.20  31.32  31.55  31.60
# 2  부산광역시  30.52  30.63  30.74  30.91  31.04  31.08
# 3  대구광역시  30.16  30.27  30.40  30.51  30.62  30.67
# 4  인천광역시  29.85  30.06  30.19  30.39  30.59  30.70

# %%
X15=X1[['2015']]
X16=X1[['2016']]
X17=X1[['2017']]
X18=X1[['2018']]
X19=X1[['2019']]
X20=X1[['2020']]
X16.rename(columns = {'2016':'2015'},inplace=True)
X17.rename(columns = {'2017':'2015'},inplace=True)
X18.rename(columns = {'2018':'2015'},inplace=True)
X19.rename(columns = {'2019':'2015'},inplace=True)
X20.rename(columns = {'2020':'2015'},inplace=True)
X1= pd.concat([X15,X16,X17,X18,X19,X20],axis=0);X1
X1.rename(columns = {'2015':'평균초혼연령'},inplace=True);X1
# Out:
# C:\Users\kim ji eun\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     평균초혼연령
# 0    29.96
# 1    30.80
# 2    30.52
# 3    30.16
# 4    29.85
# ..     ...
# 13   30.49
# 14   30.24
# 15   30.38
# 16   30.52
# 17   30.92
#
# [108 rows x 1 columns]

# %% [markdown]
# ### 2) X2: 1인가구비율

# %%
X2.head()
# Out:
#    행정구역별  2015  2016  2017  2018  2019  2020
# 0     전국  27.2  27.9  28.6  29.3  30.2  31.7
# 1  서울특별시  29.5  30.1  31.0  32.0  33.4  34.9
# 2  부산광역시  27.1  27.7  28.7  29.7  30.7  32.4
# 3  대구광역시  25.8  26.4  27.4  28.2  29.4  30.9
# 4  인천광역시  23.3  23.9  24.7  25.2  26.6  28.3

# %%
X15=X2[['2015']]
X16=X2[['2016']]
X17=X2[['2017']]
X18=X2[['2018']]
X19=X2[['2019']]
X20=X2[['2020']]
X16.rename(columns = {'2016':'2015'},inplace=True)
X17.rename(columns = {'2017':'2015'},inplace=True)
X18.rename(columns = {'2018':'2015'},inplace=True)
X19.rename(columns = {'2019':'2015'},inplace=True)
X20.rename(columns = {'2020':'2015'},inplace=True)
X2= pd.concat([X15,X16,X17,X18,X19,X20],axis=0);X2
X2.rename(columns = {'2015':'1인가구비율'},inplace=True);X2.head()
# Out:
# C:\Users\kim ji eun\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    1인가구비율
# 0    27.2
# 1    29.5
# 2    27.1
# 3    25.8
# 4    23.3

# %% [markdown]
# ### 3) X3: 행정구역별_경제활동인구

# %%
X15=X3[['2015']]
X16=X3[['2016']]
X17=X3[['2017']]
X18=X3[['2018']]
X19=X3[['2019']]
X20=X3[['2020']]
X16.rename(columns = {'2016':'2015'},inplace=True)
X17.rename(columns = {'2017':'2015'},inplace=True)
X18.rename(columns = {'2018':'2015'},inplace=True)
X19.rename(columns = {'2019':'2015'},inplace=True)
X20.rename(columns = {'2020':'2015'},inplace=True)
X3= pd.concat([X15,X16,X17,X18,X19,X20],axis=0)
X3.rename(columns = {'2015':'행정구역별_경제활동인구'},inplace=True);X3.head()
# Out:
# C:\Users\kim ji eun\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    행정구역별_경제활동인구
# 0         27260
# 1          5391
# 2          1756
# 3          1291
# 4          1567

# %% [markdown]
# ### 4) X4: 소비자물가지수

# %%
X4.head()
# Out:
#    소비자 물가지수
# 0    94.470
# 1    94.807
# 2    94.464
# 3    94.760
# 4    95.306

# %% [markdown]
# ### 5) X5: 사교육비

# %%
X5.head()
# Out:
#    행정구역별         2015         2016         2017         2018         2019  \
# 0     전국  4167.535824  4447.485399  4779.060694  5156.337520  5757.063453
# 1  서울특별시   475.578578   496.666297   556.134916   593.013508   649.169189
# 2  부산광역시   300.920593   321.537585   352.666452   360.638353   408.305571
# 3  대구광역시   325.764928   329.468424   369.519700   373.460982   403.326027
# 4  인천광역시   273.545362   278.316510   307.585325   350.561761   403.116639
#
#           2020
# 0  5746.250128
# 1   663.923546
# 2   391.919781
# 3   385.133224
# 4   397.529059

# %%
X15=X5[['2015']]
X16=X5[['2016']]
X17=X5[['2017']]
X18=X5[['2018']]
X19=X5[['2019']]
X20=X5[['2020']]
X16.rename(columns = {'2016':'2015'},inplace=True)
X17.rename(columns = {'2017':'2015'},inplace=True)
X18.rename(columns = {'2018':'2015'},inplace=True)
X19.rename(columns = {'2019':'2015'},inplace=True)
X20.rename(columns = {'2020':'2015'},inplace=True)
X5= pd.concat([X15,X16,X17,X18,X19,X20],axis=0)
X5.rename(columns = {'2015':'사교육비'},inplace=True);X5.head()
# Out:
# C:\Users\kim ji eun\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           사교육비
# 0  4167.535824
# 1   475.578578
# 2   300.920593
# 3   325.764928
# 4   273.545362

# %% [markdown]
# ### 6) X6: 유아 천명당 보육시설수

# %%
X6.head()
# Out:
#    유아 천명당 보육시설수
# 0          14.0
# 1          12.1
# 2          12.6
# 3          14.0
# 4          15.2

# %% [markdown]
# ### 7) X7: 인구밀도

# %%
X7.head()
# Out:
#     행정구역별   2015   2016   2017   2018   2019   2020
# 0      전국    509    510    512    514    516    516
# 1   서울특별시  16425  16263  16136  16023  15956  15891
# 2   부산광역시   4484   4477   4447   4420   4391   4358
# 3   대구광역시   2794   2786   2782   2772   2758   2733
# 4   인천광역시   2748   2736   2750   2761   2777   2770

# %%
X15=X7[['2015']]
X16=X7[['2016']]
X17=X7[['2017']]
X18=X7[['2018']]
X19=X7[['2019']]
X20=X7[['2020']]
X16.rename(columns = {'2016':'2015'},inplace=True)
X17.rename(columns = {'2017':'2015'},inplace=True)
X18.rename(columns = {'2018':'2015'},inplace=True)
X19.rename(columns = {'2019':'2015'},inplace=True)
X20.rename(columns = {'2020':'2015'},inplace=True)
X7= pd.concat([X15,X16,X17,X18,X19,X20],axis=0)
X7.rename(columns = {'2015':'인구밀도'},inplace=True);X7.head()
# Out:
# C:\Users\kim ji eun\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     인구밀도
# 0    509
# 1  16425
# 2   4484
# 3   2794
# 4   2748

# %% [markdown]
# #### 하나의 데이터 프레임으로 합치기(열추가)

# %%
Y['평균초혼연령']= X1['평균초혼연령']
Y['1인가구비율']= X2['1인가구비율']
Y['행정구역별_경제활동인구']= X3['행정구역별_경제활동인구']
#X4(전국데이터 포함 x)
Y['사교육비']= X5['사교육비']
#X6(전국데이터 포함 x)
Y['인구밀도']= X7['인구밀도']

# %%
Y
# Out:
#       행정구역별  합계출산율  평균초혼연령  1인가구비율  행정구역별_경제활동인구         사교육비   인구밀도
# 0        전국  1.239   29.96    27.2         27260  4167.535824    509
# 1     서울특별시  1.001   30.80    29.5          5391   475.578578  16425
# 2     부산광역시  1.139   30.52    27.1          1756   300.920593   4484
# 3     대구광역시  1.216   30.16    25.8          1291   325.764928   2794
# 4     인천광역시  1.216   29.85    23.3          1567   273.545362   2748
# ..      ...    ...     ...     ...           ...          ...    ...
# 13     전라북도  0.909   30.49    33.8           956   283.494423    224
# 14     전라남도  1.145   30.24    33.7           998   253.504198    145
# 15     경상북도  1.003   30.38    34.4          1478   262.732136    139
# 16     경상남도  0.945   30.52    30.9          1802   298.837452    317
# 17  제주특별자치도  1.021   30.92    31.1           388   328.477584    361
#
# [108 rows x 7 columns]

# %%
#전국 데이터 삭제
Y=Y.query('행정구역별!="전국"')

# %%
Y.head()
# Out:
#    행정구역별  합계출산율  평균초혼연령  1인가구비율  행정구역별_경제활동인구        사교육비   인구밀도
# 1  서울특별시  1.001   30.80    29.5          5391  475.578578  16425
# 2  부산광역시  1.139   30.52    27.1          1756  300.920593   4484
# 3  대구광역시  1.216   30.16    25.8          1291  325.764928   2794
# 4  인천광역시  1.216   29.85    23.3          1567  273.545362   2748
# 5  광주광역시  1.207   30.09    28.8           755  261.518008   3005

# %%
#행정구역별 컬럼 삭제
Y=Y.drop(['행정구역별'],axis=1)

# %%
#인덱스 재설정
Y.reset_index(inplace=True)

# %%
#인덱스 열 삭제
Y=Y.drop('index',axis=1)

# %%
#소비자물가지수, 유아 천명당 보육시설 수 열 삽입
Y.insert(4, '소비자물가지수', X4['소비자 물가지수'])

# %%
Y.insert(6, '유아 천명당 보육시설수', X6['유아 천명당 보육시설수'])

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   합계출산율         102 non-null    float64
#  1   평균초혼연령        102 non-null    float64
#  2   1인가구비율        102 non-null    float64
#  3   행정구역별_경제활동인구  102 non-null    int64
#  4   소비자물가지수       102 non-null    float64
#  5   사교육비          102 non-null    float64
#  6   유아 천명당 보육시설수  102 non-null    float64
#  7   인구밀도          102 non-null    int64
# dtypes: float64(6), int64(2)
# memory usage: 6.5 KB

# %%
Y.head()
# Out:
#    합계출산율  평균초혼연령  1인가구비율  행정구역별_경제활동인구  소비자물가지수        사교육비  유아 천명당 보육시설수  \
# 0  1.001   30.80    29.5          5391   94.470  475.578578          14.0
# 1  1.139   30.52    27.1          1756   94.807  300.920593          12.1
# 2  1.216   30.16    25.8          1291   94.464  325.764928          12.6
# 3  1.216   29.85    23.3          1567   94.760  273.545362          14.0
# 4  1.207   30.09    28.8           755   95.306  261.518008          15.2
#
#     인구밀도
# 0  16425
# 1   4484
# 2   2794
# 3   2748
# 4   3005

# %%
#csv 파일 저장
Y.to_csv('dfY_X최종.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid', font_scale=1.5)
sns.set_palette('Set2', n_colors=10)
plt.rc('font', family='malgun gothic')
plt.rc('axes', unicode_minus=False)

# %%
plt.subplots(figsize=(30,30))
sns.heatmap(Y.corr(), annot=True, fmt='0.2f', cmap="RdYlGn", linewidths=0.2);
